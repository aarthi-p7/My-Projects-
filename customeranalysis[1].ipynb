# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('customers.csv')
print(df.head())
print("\n📊 Data Summary:")
print(df.describe())
plt.figure(figsize=(5, 4))
sns.countplot(data=df, x='Gender', palette='pastel')
plt.title('Customer Gender Distribution')
plt.tight_layout()
plt.show()
plt.figure(figsize=(6, 4))
sns.histplot(df['Age'], bins=10, kde=True, color='skyblue')
plt.title('Age Distribution')
plt.tight_layout()
plt.show()
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df, x='AnnualIncome', y='SpendingScore', hue='Gender', palette='Set2')
plt.title('Income vs Spending Score')
plt.tight_layout()
plt.show()
plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='Gender', y='SpendingScore', palette='cool')
plt.title('Spending Score by Gender')
plt.tight_layout()
plt.show()
plt.figure(figsize=(5, 4))
sns.heatmap(df[['Age', 'AnnualIncome', 'SpendingScore']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Between Features')
plt.tight_layout()
plt.show()
# Out:
#    CustomerID  Gender  Age  AnnualIncome  SpendingScore
# 0           1  Female   19         15000             39
# 1           2    Male   35         30000             81
# 2           3  Female   26         40000              6
# 3           4    Male   45         50000             77
# 4           5  Female   33         60000             40
#
# 📊 Data Summary:
#        CustomerID        Age  AnnualIncome  SpendingScore
# count    6.000000   6.000000      6.000000       6.000000
# mean     3.500000  31.000000  38333.333333      53.166667
# std      1.870829   8.876936  15705.625319      29.875854
# min      1.000000  19.000000  15000.000000       6.000000
# 25%      2.250000  26.500000  31250.000000      39.250000
# 50%      3.500000  30.500000  37500.000000      58.000000
# 75%      4.750000  34.500000  47500.000000      76.750000
# max      6.000000  45.000000  60000.000000      81.000000
# C:\Users\Kavya\AppData\Local\Temp\ipykernel_18144\3950884707.py:17: FutureWarning:
#
# ...
